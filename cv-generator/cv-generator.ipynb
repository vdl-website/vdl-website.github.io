# %%
import yaml
from pathlib import Path

# only generate the citations for papers that have this person as an author
TARGET_AUTHOR = "lex"
# the students of the target author
STUDENTS = {}
# other values include paper | preprint | poster | thesis | commentary | shortpaper | workshop
PUBLICATION_TYPES = {"paper", "shortpaper", "workshop"}


PUB_DIR = Path("../_publications")

## Load all papers into the datastructure
paper_yaml = []


for file_path in PUB_DIR.iterdir():
    if not file_path.is_file():
        continue
    print(f"Processing file: {file_path.name}")
    with file_path.open("r", encoding="utf-8") as f:
        try:
            docs = yaml.safe_load_all(f)        # generator over all YAML documents in the stream
            first_doc = next(docs, None)       # get the first document (the Jekyll front matter)
            paper_yaml.append(first_doc)
        except Exception as e:
            print(f"Error reading {file_path.name}: {e}")
            paper_yaml.append(None)
            
# yaml_objects now contains the parsed front-matter object (or None on error)
# Out:
# Processing file: 2023_chi_misleading.md
# Processing file: 2025_thesis_lisnic.md
# Processing file: 2020_infovis_insights.md
# Processing file: 2024_vis_aardvark.md
# Processing file: 2025_chi_guardrails.md
# Processing file: 2013_biovis_compariseq.md
# Processing file: 2015_infovis_weaver.md
# Processing file: 2011_infovis_visbricks.md
# Processing file: 2012_infovis_dsm.md
# Processing file: 2017_vds_coresets.md
# Processing file: 2018_infovis_origraph.md
# Processing file: 2012_thesis_bigelow.md
# Processing file: 2012_biovis_enroute.md
# Processing file: 2021_ivi_intent.md
# Processing file: 2020_thesis_quinan.md
# Processing file: 2023_nsf_revisit.md
# Processing file: 2019_TBD_coresets.md
# Processing file: .DS_Store
# Error reading .DS_Store: 'utf-8' codec can't decode byte 0x80 in position 3131: invalid start byte
# Processing file: 2014_vast_contour.md
# Processing file: 2021_ivi_sanguine.md
# Processing file: 2023_thesis_rogers.md
# Processing file: 2024_vis_loops.md
# Processing file: 2014_vizsec_cyber-dashboard.md
# Processing file: 2019_infovis_clipped_graphs.md
# Processing file: 2014_nature-methods_stratomex.md
# Processing file: 2013_eurovis_poemviewer.md
# Processing file: 2009_covis_design-considerations.md
# Processing file: 2014_infovis_s-corrplot.md
# Processing file: 2021_vis_loon.md
# Processing file: 2009_cgvcvip_gaze-based.md
# Processing file: 2022_vis_data_hunches.md
# Processing file: 2018_infovis_composer.md
# Processing file: 2024_chi_yeah.md
# Processing file: 2024_thesis_gadhave.md
# Processing file: 2016_beliv_adr4v.md
# Processing file: 2017_tvcg_exploratory-wsg.md
# Processing file: 2019_infovis_arctic_explorer.md
# Processing file: 2023_thesis_lin.md
# Processing file: 2014_nature-methods_pov-sets.md
# Processing file: 2016_infovis_binning.md
# Processing file: 2010_pacificvis_caleydo.md
# Processing file: 2025_vis_reframing-pattern.md
# Processing file: 2015_infovis_vials.md
# Processing file: 2010_infovis_matchmaker.md
# Processing file: 2010_infovis_multeesum.md
# Processing file: 2012_thesis_lex.md
# Processing file: 2025_chi_crowdaloud.md
# Processing file: 2024_vis_vispubs.md
# Processing file: 2019_infovis_upset.md
# Processing file: 2014_tee_policy.md
# Processing file: 2018_ieee_epifi.md
# Processing file: 2012_tvcg_model-driven.md
# Processing file: 2018_imwut_maav.md
# Processing file: 2012_biovis_comprehengsive.md
# Processing file: 2016_eurovis_pathfinder.md
# Processing file: 2016_eurovis_clue.md
# Processing file: 2010_gi_visual-links.md
# Processing file: 2019_thesis_kerzner.md
# Processing file: 2014_chi_hidden-content.md
# Processing file: 2019_asee_air_quality.md
# Processing file: 2015_vizsec_design-methods.md
# Processing file: 2017_bioinformatics_upsetr.md
# Processing file: 2021_aas_porter.md
# Processing file: 2019_infovis_criteria.md
# Processing file: 2009_bioinformatics_caleydo.md
# Processing file: 2017_infovis_lineage.md
# Processing file: 2015_jcgs_s-corrplot.md
# Processing file: 2021_altvis_chartjunk.md
# Processing file: 2012_etra_gaze.md
# Processing file: 2017_dissertation_mckenna.md
# Processing file: 2015_infovis_poemage.md
# Processing file: README.md
# Processing file: 2010_bioinf_satsuma.md
# Processing file: 2020_vahc_sanguine.md
# Processing file: 2011_infovis_context-preserving-links.md
# Processing file: 2018_infovis_ie-framework.md
# Processing file: 2018_cga_reflection.md
# Processing file: 2025_vis_tactile-charts.md
# Processing file: 2009_ivbi_connecting-genes.md
# Processing file: 2012_beliv_nbgm.md
# Processing file: 2023_chi_troubling.md
# Processing file: 2020_beliv_extending.md
# Processing file: 2014_infovis_domino.md
# Processing file: 2019_eurovis_mvn.md
# Processing file: 2020_visshort_trrack.md
# Processing file: 2024_thesis_lange.md
# Processing file: 2022_thesis_moore.md
# Processing file: 2015_clfl_rhyme-design.md
# Processing file: 2017_infovis_fellowtoolbuilders.md
# Processing file: 2012_eurovis_stratomex.md
# Processing file: 2016_vip_resonant_lab.md
# Processing file: 2017_infovis_huebands.md
# Processing file: 2015_vdmu_ecological-validity.md
# Processing file: 2014_infovis_design-activity.md
# Processing file: 2015_eurovis_vulnerability-analysis.md
# Processing file: 2021_vis_gap.md
# Processing file: 2011_iv_filter-pipeline.md
# Processing file: 2018_tvcg_lineage.md
# Processing file: 2024_eurovis_persist.md
# Processing file: 2025_vis_data_hunch_interview.md
# Processing file: 2023_eurovis_ferret.md
# Processing file: 2019_thesis_bigelow.md
# Processing file: 2014_infovis_placement-wsv.md
# Processing file: 2017_bmc_clustering.md
# Processing file: 2023_nsf_multinet.md
# Processing file: 2019_aci_composer.md
# Processing file: 2019_plos_10-rules-network-vis.md
# Processing file: 2017_eurovis_graffinity.md
# Processing file: 2019_eurovis_implicit-discretization.md
# Processing file: 2019_ivi_taggle.md
# Processing file: 2015_eurovis_oceanpaths.md
# Processing file: 2020_tvcg_hyperlabels.md
# Processing file: 2013_infovis_entourage.md
# Processing file: 2021_chi_revisit.md
# Processing file: 2023_shortpaper_revisit.md
# Processing file: 2016_eurovis_bubble-net.md
# Processing file: 2013_cga_collaborations.md
# Processing file: 2018_infovis_juniper.md
# Processing file: 2017_eurovis_narrative-flow.md
# Processing file: 2013_ivi_nbgm.md
# Processing file: 2016_infovis_hanpuku.md
# Processing file: 2025_scientific-reports_accessibility-barriers.md
# Processing file: 2010_eurovis_pathline.md
# Processing file: 2019_shortpaper_galstamps.md
# Processing file: 2014_bmc_mu8.md
# Processing file: 2021_imwut_interview.md
# Processing file: 2019_infovis_tamax.md
# Processing file: 2017_eurova_display-space.md
# Processing file: 2012_vda_uncertainty.md
# Processing file: 2025_vis_revisit.md
# Processing file: 2014_infovis_upset.md
# Processing file: 2018_vahc_composer.md
# Processing file: 2019_vast_origraph.md
# Processing file: 2020_chi_mvnv_study.md
# Processing file: 2009_infovis_mizbee.md
# Processing file: 2022_eurovis_reusing_workflows.md
# Processing file: 2013_infovis_lineup.md
# Processing file: 2011_plos_conserved.md
# Processing file: 2020_thesis_nobre.md
# Processing file: 2019_pacificvis_jacobs_ladder.md
# Processing file: 2013_bmc_enroute.md
# Processing file: 2020_thesis_mccurdy.md
# Processing file: 2014_cga_characterizing.md
# Processing file: 2020_aaqr_pm.md
# Processing file: 2017_pdv_daf-worksheets.md
# Processing file: 2014_avi_reflections.md
# Processing file: 2025_eurovis_text-descriptions.md
# Processing file: 2018_infovis_creative-workshops.md

# %%
def getOrderNumber(order_str):
    if type(order_str) == str:
        return int(order_str.split('-')[1])
    return order_str
    

def sortAndFilterPapers(paper_yaml, targetAuthor=TARGET_AUTHOR, publicationTypes=PUBLICATION_TYPES):
    """ 
    papers are filtered to only include those with targetAuthor in authors and of type in publicationTypes 
    papers are sorted by year descending, breaking ties by order field if it exists
    """
    filteredPapers = []
    for paper in paper_yaml:
        try:
             authors = set(paper.get("authors", []))
        except Exception as e:
            continue;       
       
        if targetAuthor in authors and paper["type"] in publicationTypes:
            filteredPapers.append(paper)
    # Sort papers by "year" in descending order, break ties by field "order" if it exists
    sorted_papers = sorted(filteredPapers, key=lambda x: (x.get("year", 0), getOrderNumber(x.get("order", 0))), reverse=True)
    return sorted_papers

print(f"Loaded papers: {len(paper_yaml)}")
# Out:
# Loaded papers: 148

# %% [markdown]
# Rules for authors:
# * the TARGET_AUTHOR is set in bold
# * the students of the TARGET_AUTHOR are underlined

# %%
author_dir = Path("../_persons")

TYPES_OF_STUDENTS = ["phd_students", "ms_students", "ug_students", "phd_graduates", "former_students"]

def getStudentsOfAuthor(authorKey = TARGET_AUTHOR):
    """returns a set of author keys who are students of the given authorKey"""
    students = set()
    author_path = Path(author_dir) / f"{authorKey}.md"
    with author_path.open("r", encoding="utf-8") as f:
        try:
            docs = yaml.safe_load_all(f)        # generator over all YAML documents in the stream
            author_yaml = next(docs, None)
            for student_type in TYPES_OF_STUDENTS:
                student_list = author_yaml.get(student_type, [])
                if student_list is not None:
                    student_list = [s for s in student_list if " " not in s]
                    students.update(student_list)

        except Exception as e:
            print(f"Error reading {author_path.name}: {e}")
            return students
    return students


def resolveAuthors(authors):
    """takes a list of author keys or author names and returns a comma-separated string of author names followed by a period."""
    resolvedAuthors = ""

    # Authors can be keys (e.g., "lex") or full names (e.g., "John Doe"). Keys never have a space. 
    for author in authors:
        if (" ") in author:            
            resolvedAuthors += author + ", "
        else:
            authorKey = author
            author_path = Path(author_dir) / f"{authorKey}.md"
            # if not author_path.is_file():
            #     print(f"Error: Author file {author_path} does not exist.")
            #     continue
            
            with author_path.open("r", encoding="utf-8") as f:
                try:
                    docs = yaml.safe_load_all(f)        # generator over all YAML documents in the stream
                    author_yaml = next(docs, None)       # get the first document (the Jekyll front matter)
                    author_name = f"{author_yaml.get("first_name")} {author_yaml.get("last_name")}"
                    if authorKey == TARGET_AUTHOR:
                        author_name = f"\\textbf{{{author_name}}}"
                    if authorKey in STUDENTS: 
                        author_name = f"\\uline{{{author_name}}}"
                    resolvedAuthors += author_name + ", "
                except Exception as e:
                    print(f"Error reading {author_path.name}: {e}")
    
    return resolvedAuthors[:-2]+". "

STUDENTS = getStudentsOfAuthor(TARGET_AUTHOR)
print(STUDENTS)
resolveAuthors(["lex", "meyer", "John Doe", "zcutler"])
# Out:
# {'kiran', 'mehrpour', 'nobre', 'mukherjee', 'aljuhani', 'eliza', 'lange', 'anirudh', 'wootton', 'murali', 'sahai', 'lin', 'kern', 'pranav', 'rogers', 'mengjiao', 'lisnic', 'abrar', 'sunny', 'hardasani', 'waller', 'hannah', 'zcutler', 'cherkaev', 'zoexel', 'prajan', 'marno', 'ilkin', 'luke', 'ssiu'}
# '\\textbf{Alexander Lex}, Miriah Meyer, John Doe, \\uline{Zach Cutler}. '

# %% [markdown]
# The goal:
#
# ```latex
# \item \underline{Maxim Lisnic}, \underline{Zach Cutler}, Marina Kogan, \textbf{Alexander Lex}, \textit{Visualization Guardrails: Designing Interventions Against Cherry-Picking in Interactive Data Explorers}, SIGCHI Conference on Human Factors in Computing Systems (CHI),  pp.\ 1-19, \href{http://dx.doi.org/10.1145/3706598.3713385}{doi:10.1145/3706598.3713385}, 2025. \textbf{Best Paper Award}
# ```
#
# ```latex
# \item \underline{Devin Lange}, Robert Judson-Torres, Thomas A. Zangle, \textbf{Alexander Lex}, \textit{Aardvark: Composite Visualizations of Trees, Time-Series, and Images}, IEEE Transactions on Visualization and Computer Graphics (VIS), vol.\ 31, no.\ 1, pp.\ 1290–1300, \url{http://dx.doi.org/10.31219/osf.io/cdbm6}, 2024. \textbf{Best Paper Award.}
# ```
#
# Bibentry for journal papers:
#
# ```yaml
# bibentry: article
# bib:
#     journal: IEEE Transactions on Visualization and Computer Graphics (InfoVis)
#     booktitle:
#     editor:
#     publisher: IEEE
#     address:
#     doi: 10.1109/TVCG.2020.3030405
#     url:
#     volume: 27
#     number: 2
#     pages: 1106-1116
#     month: Feb.
# ```
#
# Bibentry for conference papers:
# ```yaml
# bibentry: inproceedings
# bib:
#   booktitle: "SIGCHI Conference on Human Factors in Computing Systems (CHI)"
#   publisher: ACM
#   doi: 10.1145/3544548.3580910
#   pages: 1-21
# ```

# %%
# we allow article | inproceedings | phdthesis | book, but only doing article/inproceedings for now

inproceedings="inproceedings"
article="article"

def generateCitation(paper):
    authors = resolveAuthors(paper.get("authors"))

    ### TITLE 
    title = f"\\textit{{{paper["title"]}}}. "
    #print(paper)
  
    ### YEAR
    year = str(paper["year"])+". "
  
    ### DOI
    try:
        doi = paper["bib"]["doi"]
        if doi is None:
            doi = ""
        else:    
            # generate  \href{http://dx.doi.org/10.1145/3706598.3713385}{doi:10.1145/3706598.3713385}, 
            doi = f"\\doi{{{doi}}}, "
    except KeyError:
        doi = ""
    
    ### PAGES
    pages = paper["bib"].get("pages", "") 
    if pages == None:
        pages = ""
    if pages != "":
        pages = f"pp.\\ {pages}, "

    ### VENUE
    venue = ""
    if(paper["bibentry"] == inproceedings):
        booktitle = paper["bib"].get("booktitle", "")
        publisher = paper["bib"].get("publisher", "")  
        if publisher is None:
            publisher = ""
        venue  = f"{publisher} {booktitle}, "  
    elif(paper["bibentry"] == article):       
        try:
            journal = paper["bib"].get("journal", "")+", "   
            venue = journal
        except Exception as e:
            print(paper)
            print("Error")
            return 
        
    ### VOLUME    
    volume = paper["bib"].get("volume", "") 
    if volume == None:
        volume = ""
    if volume != "":    
        volume = f"vol.\\ {volume}, "

    ### NUMBER
    number = paper["bib"].get("number", "")     
    if number == None:     
        number = ""
    if number != "":
        number = f"no.\\ {number}, "
    
    ### AWARD
    award = paper.get("award", "")
    if award is None:
        award = ""
    if award != "":
        award = f"\\textbf{{{award}}}"
 
    return f"\\item {authors}{title}{venue}{volume}{number}{pages}{doi}{year}{award}"  

print("final: " + generateCitation(paper_yaml[65]))
print("final: " + generateCitation(paper_yaml[1]))
print("final: " + generateCitation(paper_yaml[2]))
print("final: " + generateCitation(paper_yaml[6]))
# Out:
# final: \item \uline{Carolina Nobre}, Nils Gehlenborg, Hilary Coon, \textbf{Alexander Lex}. \textit{Lineage}.  Proceedings of the IEEE Information Visualization Conference - Posters (InfoVis), 2017.
# final: \item \uline{Maxim Lisnic}. \textit{Designing Resilient Visualizations Toward More Accurate Data Discourse}. 2025.
# final: \item \uline{Jen Rogers}, Austin H Patton, Luke Harmon, \textbf{Alexander Lex}, Miriah Meyer. \textit{Insights From Experiments With Rigor in an EvoBio Design Study}. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 27, no.\ 2, pp.\ 1106-1116, \doi{10.1109/TVCG.2020.3030405}, 2021.
# final: \item P. Samuel Quinan, Miriah Meyer. \textit{Visually Comparing Weather Features in Forecasts}. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 22, no.\ 1, pp.\ 389--398, \doi{10.1109/TVCG.2015.2467754}, 2016.

# %%
#paper_yaml = 
#shortpaper_yaml = sortAndFilterPapers(paper_yaml, TARGET_AUTHOR, {"shortpaper", "workshop"})])

def createCitationListAndWriteToFile(publication_types, filename):
    publications = sortAndFilterPapers(paper_yaml, TARGET_AUTHOR, publication_types)
    papers = []
    count = 1
    for paper in publications:
        citation = generateCitation(paper)
        papers.append(citation)
        print(count, citation)
        count += 1

    # write papers to file  
    with open(filename, "w", encoding="utf-8") as f:
        for citation in papers:
            f.write(citation + "\n")

# %%
createCitationListAndWriteToFile({"paper"}, "publications.tex")
# Out:
# 1 \item \uline{Zach Cutler}, Jack Wilburn, Hilson Shrestha, Yiren Ding, Brian Bollen, \uline{Khandaker Abrar Nadib}, Tingying He, Andrew McNutt, Lane Harrison, \textbf{Alexander Lex}. \textit{ReVISit 2: A Full Experiment Life Cycle User Study Framework}. IEEE Transactions on Visualization and Computer Graphics (VIS), vol.\ 32, 2026. \textbf{IEEE VIS 2025 Best Paper Award}
# 2 \item \uline{Haihan Lin}, \uline{Maxim Lisnic}, Derya Akbaba, Miriah Meyer, \textbf{Alexander Lex}. \textit{Here’s what you need to know about my data: Exploring Expert Knowledge’s Role in Data Analysis}. IEEE Transactions on Visualization and Computer Graphics (VIS), vol.\ 32, no.\ 1, \doi{10.1109/TVCG.2025.3634821}, 2026. \textbf{IEEE VIS 2025 Honorable Mention Award}
# 3 \item Tingying He, Maggie McCracken, Daniel Hajas, Sarah Creem-Regehr, \textbf{Alexander Lex}. \textit{Using Tactile Charts to Support Comprehension and Learning of Complex Visualizations for Blind and Low-Vision Individuals}. IEEE Transactions on Visualization and Computer Graphics (VIS), vol.\ 32, 2026.
# 4 \item Sehi L’Yi, Harrison G. Zhang, Andrew P. Mar, Thomas C. Smits, Lawrence Weru, Sofía Rojas, \textbf{Alexander Lex}, Nils Gehlenborg. \textit{A Comprehensive Evaluation of Life Sciences Data Resources Reveals Significant Accessibility Barriers}. Scientific Reports, vol.\ 15, no.\ 1, pp.\ 23676, \doi{10.1038/s41598-025-08731-7}, 2025.
# 5 \item Andrew McNutt, Maggie K McCracken, Ishrat Jahan Eliza, Daniel Hajas, Jake Wagoner, Nate Lanza, Jack Wilburn, Sarah Creem-Regehr, \textbf{Alexander Lex}. \textit{Accessible Text Descriptions for UpSet Plots}. Computer Graphics Forum (EuroVis), vol.\ 44, no.\ 3, \doi{10.1111/cgf.70102}, 2025.
# 6 \item \uline{Maxim Lisnic}, \uline{Zach Cutler}, Marina Kogan, \textbf{Alexander Lex}. \textit{Visualization Guardrails: Designing Interventions Against Cherry-Picking in Interactive Data Explorers}. ACM SIGCHI Conference on Human Factors in Computing Systems (CHI), pp.\ 1-19, \doi{10.1145/3706598.3713385}, 2025.
# 7 \item \uline{Zach Cutler}, Lane Harrison, \uline{Carolina Nobre}, \textbf{Alexander Lex}. \textit{Crowdsourced Think-Aloud Studies}. ACM SIGCHI Conference on Human Factors in Computing Systems (CHI), pp.\ 1-23, \doi{10.1145/3706598.3714305}, 2025.
# 8 \item \uline{Devin Lange}, Robert Judson-Torres, Thomas A. Zangle, \textbf{Alexander Lex}. \textit{Aardvark: Composite Visualizations of Trees, Time-Series, and Images}. IEEE Transactions on Visualization and Computer Graphics (VIS), vol.\ 31, no.\ 1, pp.\ 1290–1300, \doi{10.1109/TVCG.2024.3456193}, 2024. \textbf{IEEE VIS 2024 Best Paper Award}
# 9 \item Klaus Eckelt, \uline{Kiran Gadhave}, \textbf{Alexander Lex}, Marc Streit. \textit{Loops: Leveraging Provenance and Visualization to Support Exploratory Data Analysis in Notebooks}. IEEE Transactions on Visualization and Computer Graphics (VIS), vol.\ 31, no.\ 1, pp.\ 1213–1223, \doi{10.31219/osf.io/79eyn}, 2024.
# 10 \item \uline{Maxim Lisnic}, \textbf{Alexander Lex}, Marina Kogan. \textit{‘Yeah, this graph doesn't show that’: Analysis of Online Engagement with Misleading Data Visualizations}. ACM SIGCHI Conference on Human Factors in Computing Systems (CHI), pp.\ 1-14, \doi{10.1145/3613904.3642448}, 2024.
# 11 \item \uline{Kiran Gadhave}, \uline{Zach Cutler}, \textbf{Alexander Lex}. \textit{Persist: Persistent and Reusable Interactions in Computational Notebooks}. Computer Graphics Forum (EuroVis), vol.\ 43, no.\ 3, \doi{10.1111/cgf.15092}, 2024.
# 12 \item \uline{Devin Lange}, \uline{Shaurya Sahai}, Jeff M. Phillips, \textbf{Alexander Lex}. \textit{Ferret: Reviewing Tabular Datasets for Manipulation}. Computer Graphics Forum (EuroVis), vol.\ 42, no.\ 3, pp.\ 187-198, \doi{10.1111/cgf.14822}, 2023.
# 13 \item \uline{Maxim Lisnic}, Cole Polychronis, \textbf{Alexander Lex}, Marina Kogan. \textit{Misleading Beyond Visual Tricks: How People Actually Lie with Charts}. ACM SIGCHI Conference on Human Factors in Computing Systems (CHI), pp.\ 1-21, \doi{10.1145/3544548.3580910}, 2023.
# 14 \item Derya Akbaba, \uline{Devin Lange}, Michael Correll, \textbf{Alexander Lex}, Miriah Meyer. \textit{Troubling Collaboration: Matters of Care for Visualization Design Study}. ACM SIGCHI Conference on Human Factors in Computing Systems (CHI), pp.\ 1-15, \doi{10.1145/3544548.3581168}, 2023.
# 15 \item \uline{Haihan Lin}, Derya Akbaba, Miriah Meyer, \textbf{Alexander Lex}. \textit{Data Hunches: Incorporating Personal Knowledge into Visualizations}. , vol.\ 29, no.\ 1, pp.\ 504-514, \doi{10.1109/TVCG.2022.3209451}, 2022.
# 16 \item \uline{Kiran Gadhave}, \uline{Zach Cutler}, \textbf{Alexander Lex}. \textit{Reusing Interactive Analysis Workflows}. Computer Graphics Forum (EuroVis), vol.\ 41, no.\ 3, pp.\ 133–144, \doi{10.1111/cgf.14528}, 2022.
# 17 \item \uline{Devin Lange}, Eddie Polanco, Robert Judson-Torres, Thomas A. Zangle, \textbf{Alexander Lex}. \textit{Loon: Using Exemplars to Visualize Large-Scale Microscopy Data}. IEEE Transactions on Visualization and Computer Graphics (VIS), vol.\ 28, no.\ 1, pp.\ 248-258, \doi{10.1109/TVCG.2021.3114766}, 2021. \textbf{IEEE VIS 2021 Honorable Mention Award}
# 18 \item \uline{Kiran Gadhave}, Jochen Görtler, \uline{Zach Cutler}, \uline{Carolina Nobre}, Oliver Deussen, Miriah Meyer, Jeff Phillips, \textbf{Alexander Lex}. \textit{Predicting Intent Behind Selections in Scatterplot Visualizations}. Information Visualization, vol.\ 20, no.\ 4, pp.\ 207–228, \doi{10.1177/14738716211038604}, 2021.
# 19 \item \uline{Jen Rogers}, Austin H Patton, Luke Harmon, \textbf{Alexander Lex}, Miriah Meyer. \textit{Insights From Experiments With Rigor in an EvoBio Design Study}. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 27, no.\ 2, pp.\ 1106-1116, \doi{10.1109/TVCG.2020.3030405}, 2021.
# 20 \item \uline{Haihan Lin}, Ryan A. Metcalf, Jack Wilburn, \textbf{Alexander Lex}. \textit{Sanguine: Visual Analysis for Patient Blood Management}. Information Visualization, vol.\ 20, no.\ 2-3, pp.\ 123-137, \doi{10.1177/14738716211028565}, 2021.
# 21 \item \uline{Carolina Nobre}, \uline{Dylan Wootton}, \uline{Zach Cutler}, Lane Harrison, Hanspeter Pfister, \textbf{Alexander Lex}. \textit{reVISit: Looking Under the Hood of Interactive Visualization Studies}. ACM SIGCHI Conference on Human Factors in Computing Systems (CHI), pp.\ 1-13, \doi{10.1145/3411764.3445382}, 2021.
# 22 \item \uline{Carolina Nobre}, \uline{Dylan Wootton}, Lane Harrison, \textbf{Alexander Lex}. \textit{Evaluating Multivariate Network Visualization Techniques Using a Validated Design and Crowdsourcing Approach}. ACM SIGCHI Conference on Human Factors in Computing Systems (CHI), pp.\ 1-12, \doi{10.1145/3313831.3376381}, 2020.
# 23 \item Katarina Furmanova, Samuel Gratzl, Holger Stitz, Thomas Zichner, Miroslava Jaresova, \textbf{Alexander Lex}, Marc Streit. \textit{Taggle: Scalable Visualization of Tabular Data through Aggregation}. Information Visualization, vol.\ 19, no.\ 2, pp.\ 114-136, \doi{10.1177/1473871619878085}, 2019.
# 24 \item Alex Bigelow, \uline{Carolina Nobre}, Miriah Meyer, \textbf{Alexander Lex}. \textit{Origraph: Interactive Network Wrangling}.  IEEE Conference on Visual Analytics Science and Technology (VAST), pp.\ 81-92, \doi{10.1109/VAST47406.2019.8986909}, 2019.
# 25 \item G. Elisabeta Marai, Bruno Pinaud, Katja Bühler, \textbf{Alexander Lex}, John H. Morris. \textit{Ten Simple Rules to Create Biological Network Figures for Communication}. PLOS Computational Biology, vol.\ 15, no.\ 9, pp.\ e1007244, \doi{10.1371/journal.pcbi.1007244}, 2019.
# 26 \item \uline{Carolina Nobre}, Marc Streit, Miriah Meyer, \textbf{Alexander Lex}. \textit{The State of the Art in Visualizing Multivariate Networks}. Computer Graphics Forum (EuroVis), vol.\ 38, pp.\ 807-832, \doi{10.1111/cgf.13728}, 2019.
# 27 \item \uline{Jen Rogers}, Nicholas Spina, Ashley Neese, Rachel Hess, Darrel Brodke, \textbf{Alexander Lex}. \textit{Composer: Visual Cohort Analysis of Patient Outcomes}. Applied Clinical Informatics, vol.\ 10, no.\ 2, pp.\ 278-285, \doi{10.1055/s-0039-1687862}, 2019.
# 28 \item \uline{Carolina Nobre}, Marc Streit, \textbf{Alexander Lex}. \textit{Juniper: A Tree+Table Approach to Multivariate Graph Visualization}. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 25, no.\ 1, pp.\ 544-554, \doi{10.1109/TVCG.2018.2865149}, 2019.
# 29 \item \uline{Carolina Nobre}, Nils Gehlenborg, Hilary Coon, \textbf{Alexander Lex}. \textit{Lineage: Visualizing Multivariate Clinical Data in Genealogy Graphs}. IEEE Transactions on Visualization and Computer Graphics, vol.\ 25, no.\ 3, pp.\ 1543-1558, \doi{10.1109/TVCG.2018.2811488}, 2019.
# 30 \item Yan Zheng, Yi Ou, \textbf{Alexander Lex}, Jeff M. Phillips. \textit{Visualization of Big Spatial Data using Coresets for Kernel Density Estimates}. IEEE Transactions on Big Data, vol.\ 7, no.\ 3, pp.\ 524-534, \doi{10.1109/TBDATA.2019.2913655}, 2019.
# 31 \item Yan Zheng, Yi Ou, \textbf{Alexander Lex}, Jeff M. Phillips. \textit{Visualization of Big Spatial Data using Coresets for Kernel Density Estimates}. IEEE IEEE Symposium on Visualization in Data Science (VDS), \doi{10.1109/VDS.2017.8573446}, 2017.
# 32 \item Jake R. Conway, \textbf{Alexander Lex}, Nils Gehlenborg. \textit{UpSetR: An R Package For The Visualization Of Intersecting Sets And Their Properties}. Bioinformatics, vol.\ 33, no.\ 18, pp.\ 2938-2940, \doi{10.1093/bioinformatics/btx364}, 2017.
# 33 \item \uline{Michael Kern}, \textbf{Alexander Lex}, Nils Gehlenborg, Chris R. Johnson. \textit{Interactive Visual Exploration And Refinement Of Cluster Assignments}. BMC Bioinformatics, vol.\ 18, no.\ 1, pp.\ 406, \doi{10.1186/s12859-017-1813-7}, 2017.
# 34 \item Ethan Kerzner, \textbf{Alexander Lex}, Crystal Lynn Sigulinsky, Timothy Urness, Bryan William Jones, Robert E. Marc, Miriah Meyer. \textit{Graffinity: Visualizing Connectivity In Large Graphs}. Computer Graphics Forum (EuroVis), vol.\ 36, no.\ 3, pp.\ 251-260, \doi{10.1111/cgf.13184}, 2017.
# 35 \item Hendrik Strobelt, Bilal Alsallakh, Joseph Botors, Brant Peterson, Mark Borowsky, Hanspeter Pfister, \textbf{Alexander Lex}. \textit{Vials: Visualizing Alternative Splicing of Genes}. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 22, no.\ 1, pp.\ 399--408, \doi{10.1109/TVCG.2015.2467911}, 2016.
# 36 \item Christian Partl, Samuel Gratzl, Marc Streit, Anne Mai Wassermann, Hanspeter Pfister, Dieter Schmalstieg, \textbf{Alexander Lex}. \textit{Pathfinder: Visual Analysis of Paths in Graphs}. Computer Graphics Forum (EuroVis), vol.\ 35, no.\ 3, pp.\ 71--80, \doi{10.1111/cgf.12883}, 2016. \textbf{EuroVis 2016 Honorable Mention Award}
# 37 \item Samuel Gratzl, \textbf{Alexander Lex}, Nils Gehlenborg, Nicola Cosgrove, Marc Streit. \textit{From Visual Exploration to Storytelling and Back Again}. Computer Graphics Forum (EuroVis), vol.\ 35, no.\ 3, pp.\ 491--500, \doi{10.1111/cgf.12925}, 2016.
# 38 \item Christian Partl, \textbf{Alexander Lex}, Hendrik Strobelt, Anne Mai Wassermann, Hanspeter Pfister, Dieter Schmalstieg. \textit{ConTour: Data-Driven Exploration of Multi-Relational Datasets for Drug Discovery}. IEEE Transactions on Visualization and Computer Graphics (VAST), vol.\ 20, no.\ 12, pp.\ 1883--1892, \doi{10.1109/TVCG.2014.2346752}, 2014.
# 39 \item Marc Streit, \textbf{Alexander Lex}, Samuel Gratzl, Christian Partl, Dieter Schmalstieg, Hanspeter Pfister, Peter Park, Nils Gehlenborg. \textit{Guided Visual Exploration of Genomic Stratifications in Cancer}. Nature Methods, vol.\ 11, no.\ 9, pp.\ 884--885, \doi{10.1038/nmeth.3088}, 2014.
# 40 \item Thomas Geymayer, Markus Steinberger, \textbf{Alexander Lex}, Marc Streit, Dieter Schmalstieg. \textit{Show me the Invisible: Visualizing Hidden Content}. ACM Press Proceedings of the SIGCHI Conference on Human Factors in Computing Systems (CHI), pp.\ 3705--3714, \doi{10.1145/2556288.2557032}, 2014. \textbf{ACM CHI 2014 Honorable Mention Award}
# 41 \item Samuel Gratzl, Nils Gehlenborg, \textbf{Alexander Lex}, Hanspeter Pfister, Marc Streit. \textit{Domino: Extracting, Comparing, and Manipulating Subsets across Multiple Tabular Datasets }. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 20, no.\ 12, pp.\ 2023--2032, \doi{10.1109/TVCG.2014.2346260}, 2014. \textbf{IEEE InfoVis 2014 Honorable Mention Award}
# 42 \item Johnathan D Mercer, Balaji Pandian, \textbf{Alexander Lex}, Nicolas Bonnel, Hanspeter Pfister. \textit{Mu-8: Visualizing Differences between Proteins and their Families}. BMC Proceedings, vol.\ 8, no.\ Suppl 2, pp.\ S5, \doi{10.1186/1753-6561-8-S2-S5}, 2014.
# 43 \item \textbf{Alexander Lex}, Nils Gehlenborg, Hendrik Strobelt, Romain Vuillemot, Hanspeter Pfister. \textit{UpSet: Visualization of Intersecting Sets}. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 20, no.\ 12, pp.\ 1983--1992, \doi{10.1109/TVCG.2014.2346248}, 2014. \textbf{10 Year InfoVis Test of Time Award, 2024}
# 44 \item Cagatay Turkay, \textbf{Alexander Lex}, Marc Streit, Hanspeter Pfister, Helwig Hauser. \textit{Characterizing Cancer Subtypes using the Dual Analysis Approach in Caleydo StratomeX}. IEEE Computer Graphics and Applications, vol.\ 34, no.\ 2, pp.\ 38--47, \doi{10.1109/MCG.2014.1}, 2014.
# 45 \item \textbf{Alexander Lex}, Christian Partl, Denis Kalkofen, Marc Streit, Anne Mai Wassermann, Samuel Gratzl, Dieter Schmalstieg, Hanspeter Pfister. \textit{Entourage: Visualizing Relationships between Biological Pathways using Contextual Subsets}. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 19, no.\ 12, pp.\ 2536--2545, \doi{10.1109/TVCG.2013.154}, 2013.
# 46 \item Samuel Gratzl, \textbf{Alexander Lex}, Nils Gehlenborg, Hanspeter Pfister, Marc Streit. \textit{LineUp: Visual Analysis of Multi-Attribute Rankings}. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 19, no.\ 12, pp.\ 2277--2286, \doi{10.1109/TVCG.2013.173}, 2013. \textbf{IEEE InfoVis 2013 Best Paper Award}
# 47 \item Christian Partl, \textbf{Alexander Lex}, Marc Streit, Denis Kalkofen, Karl Kashofer, Dieter Schmalstieg. \textit{enRoute: Dynamic Path Extraction from Biological Pathway Maps for Exploring Heterogeneous Experimental Datasets}. BMC Bioinformatics, vol.\ 14, no.\ Suppl 19, pp.\ S3, \doi{10.1186/1471-2105-14-S19-S3}, 2013.
# 48 \item Christian Partl, \textbf{Alexander Lex}, Marc Streit, Denis Kalkofen, Karl Kashofer, Dieter Schmalstieg. \textit{enRoute: Dynamic Path Extraction from Biological Pathway Maps for In-Depth Experimental Data Analysis}.  Proceedings of the IEEE Symposium on Biological Data Visualization (BioVis), pp.\ 107–114, \doi{10.1109/BioVis.2012.6378600}, 2012. \textbf{IEEE BioVis 2012 Best Paper Award}
# 49 \item Marc Streit, Hans-Jörg Schulz, \textbf{Alexander Lex}, Dieter Schmalstieg, Heidrun Schumann. \textit{Model-Driven Design for the Visual Analysis of Heterogeneous Data }. IEEE Transactions on Visualization and Computer Graphics, vol.\ 18, no.\ 6, pp.\ 998--1010, \doi{10.1109/TVCG.2011.108}, 2012.
# 50 \item \textbf{Alexander Lex}, Marc Streit, Hans-Jörg Schulz, Christian Partl, Dieter Schmalstieg, Peter Park, Nils Gehlenborg. \textit{StratomeX: Visual Analysis of Large-Scale Heterogeneous Genomics Data for Cancer Subtype Characterization}. Computer Graphics Forum (EuroVis), vol.\ 31, no.\ 3, pp.\ 1175--1184, \doi{10.1111/j.1467-8659.2012.03110.x}, 2012. \textbf{EuroVis 2012 3rd Best Paper Award}
# 51 \item Clemens Holzhüter, \textbf{Alexander Lex}, Dieter Schmalstieg, Hans-Jörg Schulz, Heidrun Schumann, Marc Streit. \textit{Visualizing Uncertainty in Biological Expression Data}.  Proceedings of the SPIE Conference on Visualization and Data Analysis (VDA), vol.\ 8294, pp.\ 82940O-82940O-11, \doi{10.1117/12.908516}, 2012.
# 52 \item \textbf{Alexander Lex}, Hans-Jörg Schulz, Marc Streit, Christian Partl, Dieter Schmalstieg. \textit{VisBricks: Multiform Visualization of Large, Inhomogeneous Data }. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 17, no.\ 12, pp.\ 2291--2300, \doi{10.1109/TVCG.2011.250}, 2011.
# 53 \item Markus Steinberger, Manuela Waldner, Marc Streit, \textbf{Alexander Lex}, Dieter Schmalstieg. \textit{Context-Preserving Visual Links}. IEEE Transactions on Visualization and Computer Graphics (InfoVis'11), vol.\ 17, no.\ 12, pp.\ 2249--2258, \doi{10.1109/TVCG.2011.183}, 2011. \textbf{IEEE InfoVis 2011 Best Paper Award}
# 54 \item Thomas Geymayer, \textbf{Alexander Lex}, Marc Streit, Dieter Schmalstieg. \textit{Visualizing the Effects of Logically Combined Filters}. IEEE Computer Society Press Proceedings of the Conference on Information Visualisation (IV), pp.\ 47–52, \doi{10.1109/IV.2011.52}, 2011.
# 55 \item \textbf{Alexander Lex}, Marc Streit, Ernst Kruijff, Dieter Schmalstieg. \textit{Caleydo: Design and Evaluation of a Visual Analysis Framework for Gene Expression Data in its Biological Context}.  Proceedings of IEEE Pacific Visualization Symposium (PacificVis), pp.\ 57--64, \doi{10.1109/PACIFICVIS.2010.5429609}, 2010.
# 56 \item \textbf{Alexander Lex}, Marc Streit, Christian Partl, Karl Kashofer, Dieter Schmalstieg. \textit{Comparative Analysis of Multidimensional, Quantitative Data }. IEEE Transactions on Visualization and Computer Graphics (InfoVis), vol.\ 16, no.\ 6, pp.\ 1027--1035, \doi{10.1109/TVCG.2010.138}, 2010.
# 57 \item Manuela Waldner, Werner Puff, \textbf{Alexander Lex}, Marc Streit, Dieter Schmalstieg. \textit{Visual Links across Applications}. Canadian Human-Computer Communications Society Proceedings of the Graphics Interface (GI), pp.\ 129–136, \doi{10.5555/1839214.1839238}, 2010. \textbf{GI 2010 Best Student Paper Award}
# 58 \item Marc Streit, \textbf{Alexander Lex}, Michael Kalkusch, Kurt Zatloukal, Dieter Schmalstieg. \textit{Caleydo: Connecting Pathways with Gene Expression}. Bioinformatics, vol.\ 25, no.\ 20, pp.\ 2760–2761, \doi{10.1093/bioinformatics/btp432}, 2009.
# 59 \item Heimo Müller, Robert Reihs, Stefan Sauer, Kurt Zatloukal, Marc Streit, \textbf{Alexander Lex}, Bernhard Schlegl, Dieter Schmalstieg. \textit{Connecting Genes with Diseases}.  Proceedings of the Conference on Information Visualisation (IV), pp.\ 323--330, \doi{10.1109/IV.2009.86}, 2009.

# %%
createCitationListAndWriteToFile({"workshop", "shortpaper"}, "workshopshort.tex")
# Out:
# 1 \item Yiren Ding, Jack Wilburn, Hilson Shrestha, Akim Ndlovu, \uline{Kiran Gadhave}, \uline{Carolina Nobre}, \textbf{Alexander Lex}, Lane Harrison. \textit{reVISit: Supporting Scalable Evaluation of Interactive Visualizations}. IEEE IEEE Visualization and Visual Analytics (VIS), pp.\ 31-35, \doi{10.1109/VIS54172.2023.00015}, 2023.
# 2 \item \uline{Haihan Lin}, Ryan A. Metcalf, Jack Wilburn, \textbf{Alexander Lex}. \textit{Sanguine: Visual Analysis for Patient Blood Management}.  Workshop on Visual Analytics in Healthcare at AMIA (VAHC), 2020.
# 3 \item \uline{Zach Cutler}, \uline{Kiran Gadhave}, \textbf{Alexander Lex}. \textit{Trrack: A Library for Provenance-Tracking in Web-Based Visualizations}.  IEEE Visualization Conference (VIS), pp.\ 116-120, \doi{10.1109/VIS47514.2020.00030}, 2020.
# 4 \item \uline{Jen Rogers}, Nicholas Spina, Ashley Neese, Rachel Hess, Darrel Brodke, \textbf{Alexander Lex}. \textit{Composer: Visual Cohort Analysis of Patient Outcomes}.  Workshop on Visual Analytics in Healthcare at AMIA (VAHC 2018), 2018.
# 5 \item Thomas Geymayer, Manuela Waldner, \textbf{Alexander Lex}, Dieter Schmalstieg. \textit{How Sensemaking Tools Influence Display Space Usage}. The Eurographics Association EuroVis Workshop on Visual Analytics (EuroVA), \doi{10.2312/eurova.20171112}, 2017.
# 6 \item Sean McKenna, \textbf{Alexander Lex}, Miriah Meyer. \textit{Worksheets for Guiding Novices through the Visualization Design Process}. IEEE Workshop on Pedagogy of Data Visualization (PDV), \doi{10.48550/arXiv.1709.05723}, 2017.
# 7 \item \uline{Carolina Nobre}, \textbf{Alexander Lex}. \textit{OceanPaths: Visualizing Multivariate Oceanography Data}. The Eurographics Association Proceedings of the Eurographics Conference on Visualization (EuroVis) - Short Papers, \doi{10.2312/eurovisshort.20151124}, 2015.
# 8 \item Manuela Waldner, \textbf{Alexander Lex}, Marc Streit, Dieter Schmalstieg. \textit{Design Considerations for Collaborative Information Workspaces in Multi-Display Environments}.  Proceedings of Workshop on Collaborative Visualization on Interactive Surfaces (CoVIS'09, VisWeek), pp.\ 36--39, 2009.
# 9 \item Marc Streit, \textbf{Alexander Lex}, Heimo Müller, Dieter Schmalstieg. \textit{Gaze-Based Focus Adaption in an Information Visualization System}. IADIS Proceedings of the Conference on Computer Graphics and Visualization and Image Processing (CGVCVIP), 2009.
